# %% [markdown]
# ## Clean A/B test results

# %% [markdown]
# My version of pandas : '1.0.3'
# Old version of pandas : 0.25.1

# %%
import gym, recogym
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import pandas as pd
import pickle as pkl
from recogym.envs.utils_sale import format_avg_result, avg_result, format_avg_result_extended, avg_result_extended

# %%
# Repository to save pickles
repo = 'data_conversion_big/data_conversion/clean/'

# %%
name = 'prescl_mem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap

# %% [markdown]
# ## Click + mem

# %%
name = 'prescl_mem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap

# %%
name = 'propcl_mem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap

# %%
name = 'prescl_mem'
res_avg_ = pkl.load(open(repo+'res_avg_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg_
# Out:
# {'CTR':                                    Agent     0.025     0.500     0.975  \
#  0                                 rand10  0.009416  0.009719  0.010029
#  1            likelihood_logreg_clickpres  0.015144  0.015527  0.015916
#  2            likelihood_logreg_postdpres  0.007861  0.008137  0.008420
#  3           likelihood_saleclickprodpres  0.014922  0.015302  0.015688
#  4  likelihood_saleclickprod_discountpres  0.013384  0.013745  0.014111
#
#         Mean       std        se
#  0  0.009905  0.000168  0.000034
#  1  0.015828  0.000194  0.000039
#  2  0.008114  0.000145  0.000029
#  3  0.015598  0.000229  0.000046
#  4  0.013948  0.000218  0.000044  ,
#  'Tot sales ATT':                                    Agent  TotSalesAtt     Mean        std  \
#  0                                 rand10         1128  1173.24  39.753521
#  1            likelihood_logreg_clickpres         1955  1989.64  52.110559
#  2            likelihood_logreg_postdpres          925   939.36  38.573442
# ...

# %%
name = 'prescl_mem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap
# Out:
# prescl_mem
#    Agent              CTR  Att Sales          Att CR       Sales  \
# 0   Rand  0.990 (0.003) %   1173 (7)  18.28 (0.10) %   9802 (42)
# 1  Click  1.583 (0.004) %  1989 (10)  26.92 (0.10) %  11348 (47)
# 2    PVS  0.811 (0.003) %    939 (7)  15.39 (0.10) %   9275 (36)
# 3    PCS  1.560 (0.005) %  1960 (10)  26.63 (0.11) %  11262 (48)
# 4   DPCS  1.395 (0.004) %   1733 (9)  24.22 (0.10) %  10866 (46)
#
#                CR         True CTR        True PCS        True OS  \
# 0  60.67 (0.14) %  0.963 (0.000) %  10.83 (0.01) %  7.52 (0.02) %
# 1  63.91 (0.14) %  1.540 (0.001) %  11.92 (0.01) %  7.75 (0.02) %
# 2  59.68 (0.15) %  0.788 (0.001) %  11.68 (0.01) %  9.40 (0.02) %
# 3  63.61 (0.15) %  1.516 (0.002) %  11.87 (0.01) %  7.79 (0.02) %
# 4  62.93 (0.14) %  1.355 (0.002) %  11.60 (0.01) %  7.90 (0.02) %
#
#          True NCS              NDPC             DPCSO             DPCSN
# 0   8.74 (0.01) %  1.043 (0.001) pm  0.319 (0.001) pm  0.201 (0.000) pm
# ...

# %%
name = 'propcl_mem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap
# Out:
# propcl_mem
#   Agent              CTR Att Sales          Att CR      Sales              CR  \
# 0  Rand  0.990 (0.003) %  1173 (7)  18.28 (0.10) %  9802 (42)  60.67 (0.14) %
# 1   PCS  1.020 (0.003) %  1230 (8)  18.39 (0.09) %  9807 (41)  60.51 (0.15) %
# 2  DPCS  0.964 (0.004) %  1162 (7)  17.72 (0.11) %  9701 (42)  60.29 (0.16) %
#
#           True CTR        True PCS        True OS       True NCS  \
# 0  0.963 (0.000) %  10.83 (0.01) %  7.52 (0.02) %  8.74 (0.01) %
# 1  0.995 (0.002) %  10.96 (0.01) %  7.82 (0.02) %  9.08 (0.02) %
# 2  0.936 (0.002) %  10.90 (0.01) %  7.72 (0.02) %  8.95 (0.01) %
#
#                NDPC             DPCSO             DPCSN
# 0  1.043 (0.001) pm  0.319 (0.001) pm  0.201 (0.000) pm
# 1  1.090 (0.003) pm  0.312 (0.001) pm  0.187 (0.000) pm
# 2  1.020 (0.002) pm  0.298 (0.001) pm  0.182 (0.000) pm

# %% [markdown]
# ## Click + No memory

# %%
name = 'presweightscl_nomem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap
# Out:
# presweightscl_nomem
#    Agent              CTR Att Sales          Att CR       Sales  \
# 0   Rand  0.990 (0.002) %  1175 (5)  18.30 (0.08) %   9785 (27)
# 1  Click  1.469 (0.003) %  1864 (7)  25.48 (0.08) %  11168 (29)
# 2    PVS  0.946 (0.002) %  1134 (6)  17.65 (0.08) %   9719 (31)
# 3    PCS  1.349 (0.003) %  1717 (7)  24.05 (0.07) %  10892 (30)
# 4   DPCS  1.120 (0.003) %  1407 (6)  20.83 (0.08) %  10407 (30)
#
#                CR         True CTR        True PCS        True OS  \
# 0  60.56 (0.09) %  0.963 (0.000) %  10.82 (0.01) %  7.51 (0.01) %
# 1  63.27 (0.10) %  1.428 (0.001) %  11.90 (0.01) %  7.57 (0.02) %
# 2  60.30 (0.10) %  0.920 (0.001) %  11.48 (0.01) %  8.34 (0.01) %
# 3  62.70 (0.11) %  1.312 (0.001) %  11.93 (0.01) %  7.70 (0.02) %
# 4  61.79 (0.09) %  1.091 (0.001) %  11.85 (0.01) %  7.57 (0.01) %
#
#         True NCS              NDPC             DPCSO             DPCSN
# 0  8.73 (0.01) %  1.043 (0.001) pm  0.320 (0.001) pm  0.202 (0.000) pm
# ...

# %%
name = 'propweightscl_nomem'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_AB
res_recap
# Out:
# propweightscl_nomem
#   Agent              CTR Att Sales          Att CR      Sales              CR  \
# 0  Rand  0.990 (0.002) %  1175 (5)  18.30 (0.08) %  9785 (27)  60.56 (0.09) %
# 1   PCS  0.940 (0.002) %  1098 (5)  16.94 (0.08) %  9585 (26)  60.31 (0.09) %
# 2  DPCS  0.928 (0.002) %  1085 (5)  16.79 (0.08) %  9559 (26)  60.23 (0.09) %
#
#           True CTR        True PCS        True OS       True NCS  \
# 0  0.963 (0.000) %  10.82 (0.01) %  7.51 (0.01) %  8.73 (0.01) %
# 1  0.911 (0.001) %  10.55 (0.01) %  7.44 (0.01) %  8.70 (0.01) %
# 2  0.899 (0.001) %  10.51 (0.01) %  7.42 (0.01) %  8.66 (0.01) %
#
#                NDPC             DPCSO             DPCSN
# 0  1.043 (0.001) pm  0.320 (0.001) pm  0.202 (0.000) pm
# 1  0.961 (0.002) pm  0.284 (0.001) pm  0.169 (0.000) pm
# 2  0.945 (0.002) pm  0.277 (0.001) pm  0.166 (0.000) pm

# %%
name = 'pres'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_recap
# Out:
# pres
#    Agent              CTR Att Sales          Att CR       Sales  \
# 0   Rand  0.990 (0.002) %  1177 (6)  18.33 (0.08) %   9800 (29)
# 1  Click  1.597 (0.003) %  2012 (8)  27.02 (0.08) %  11385 (32)
# 2    PVS  0.805 (0.002) %   931 (5)  15.22 (0.07) %   9245 (25)
# 3    PCS  1.571 (0.003) %  1980 (8)  26.67 (0.08) %  11285 (33)
# 4   DPCS  1.397 (0.003) %  1738 (6)  24.17 (0.07) %  10842 (30)
#
#                CR         True CTR        True PCS        True OS  \
# 0  60.56 (0.08) %  0.963 (0.000) %  10.83 (0.01) %  7.52 (0.01) %
# 1  63.81 (0.09) %  1.553 (0.001) %  11.94 (0.01) %  7.76 (0.01) %
# 2  59.46 (0.09) %  0.784 (0.001) %  11.67 (0.01) %  9.46 (0.01) %
# 3  63.49 (0.10) %  1.527 (0.001) %  11.88 (0.01) %  7.81 (0.01) %
# 4  62.70 (0.09) %  1.359 (0.001) %  11.58 (0.01) %  7.91 (0.01) %
#
#          True NCS              NDPC             DPCSO             DPCSN
# 0   8.74 (0.01) %  1.043 (0.001) pm  0.319 (0.001) pm  0.201 (0.000) pm
# ...

# %%
name = 'prop'
res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
res_avg = avg_result_extended(res_dict)
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg,print_res=False) 
print(name)
res_recap
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-fa2c421c6199> in <module>
#       1 name = 'prop'
# ----> 2 res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))
#       3 res_avg = avg_result_extended(res_dict)
#       4 (res_recap, res_recap_latex,
#       5  res_AB, res_AB_latex,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_conversion_big/data_conversion/clean/res_dict_rand105000_5000_v_shareprop.pkl'

# %%
name = 'prop'

res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))

# for metric, colname in [("CTR",'0.500'),("Tot sales ATT",'TotSalesAtt'),('Share user with sale ATT','0.500'),
#                         ("Tot sales",'TotSales'),('Share user with sale','0.500')]:
#     res_dict[metric]["Mean"] = res_avg[metric][colname]

for metric, colname in [("CTR",'0.500'),("Tot sales ATT",'TotSalesAtt'),('Share user with sale ATT','0.500'),
                        ("Tot sales",'TotSales'),('Share user with sale','0.500')]:
    print(metric)
    res = deepcopy(res_dict['rand105000_5000_v_share'+name+'_nb0'][metric])
    for nb in res_dict.keys():
#         print(res_dict[nb][metric][colname])
        res[colname] += res_dict[nb][metric][colname]
    res[colname] = res[colname]/50
    display(res)
# Out:
# CTR
#                                    Agent     0.025     0.500     0.975
# 0                                 rand10  0.009458  0.010095  0.010071
# 1           likelihood_saleclickprodprop  0.009783  0.010487  0.010405
# 2  likelihood_saleclickprod_discountprop  0.009124  0.009827  0.009725
# Tot sales ATT
#                                    Agent  TotSalesAtt
# 0                                 rand10      1199.50
# 1           likelihood_saleclickprodprop      1272.20
# 2  likelihood_saleclickprod_discountprop      1190.58
# Share user with sale ATT
#                                    Agent     0.025     0.500     0.975
# 0                                 rand10  0.168040  0.186866  0.189261
# 1           likelihood_saleclickprodprop  0.172335  0.189765  0.193759
# 2  likelihood_saleclickprod_discountprop  0.159651  0.181044  0.180463
# Tot sales
#                                    Agent  TotSales
# 0                                 rand10   9995.48
# ...

# %%
name = 'pres'

res_dict = pkl.load(open(repo+'res_dict_rand105000_5000_v_share'+name+'.pkl','rb'))

# for metric, colname in [("CTR",'0.500'),("Tot sales ATT",'TotSalesAtt'),('Share user with sale ATT','0.500'),
#                         ("Tot sales",'TotSales'),('Share user with sale','0.500')]:
#     res_dict[metric]["Mean"] = res_avg[metric][colname]

for metric, colname in [("CTR",'0.500'),("Tot sales ATT",'TotSalesAtt'),('Share user with sale ATT','0.500'),
                        ("Tot sales",'TotSales'),('Share user with sale','0.500')]:
    print(metric)
    res = deepcopy(res_dict['rand105000_5000_v_share'+name+'_nb0'][metric])
    for nb in res_dict.keys():
#         print(res_dict[nb][metric][colname])
        res[colname] += res_dict[nb][metric][colname]
    res[colname] = res[colname]/50
    display(res)
# Out:
# CTR
#                                    Agent     0.025     0.500     0.975
# 0                                 rand10  0.009458  0.010095  0.010071
# 1            likelihood_logreg_clickpres  0.015224  0.016284  0.015998
# 2            likelihood_logreg_postdpres  0.007823  0.008208  0.008382
# 3           likelihood_saleclickprodpres  0.014994  0.016014  0.015762
# 4  likelihood_saleclickprod_discountpres  0.013398  0.014244  0.014125
# Tot sales ATT
#                                    Agent  TotSalesAtt
# 0                                 rand10      1199.50
# 1            likelihood_logreg_clickpres      2052.08
# 2            likelihood_logreg_postdpres       949.76
# 3           likelihood_saleclickprodpres      2018.88
# 4  likelihood_saleclickprod_discountpres      1772.34
# Share user with sale ATT
#                                    Agent     0.025     0.500     0.975
# 0                                 rand10  0.168040  0.186866  0.189261
# ...

# %%
res_dict
# Out:
# {'rand105000_5000_v_sharepres_nb0': {'CTR':                                    Agent     0.025     0.500     0.975
#   0                                 rand10  0.009458  0.009761  0.010071
#   1            likelihood_logreg_clickpres  0.015224  0.015608  0.015998
#   2            likelihood_logreg_postdpres  0.007823  0.008099  0.008382
#   3           likelihood_saleclickprodpres  0.014994  0.015375  0.015762
#   4  likelihood_saleclickprod_discountpres  0.013398  0.013758  0.014125,
#   'Tot sales ATT':                                    Agent  TotSalesAtt
#   0                                 rand10         1103
#   1            likelihood_logreg_clickpres         1973
#   2            likelihood_logreg_postdpres          918
#   3           likelihood_saleclickprodpres         1944
#   4  likelihood_saleclickprod_discountpres         1715,
#   'Share user with sale ATT':                                    Agent     0.025     0.500     0.975
# ...

# %%
res_avg = avg_result_extended(res_dict)

# %%
res_avg
# Out:
# {'CTR':                                    Agent     0.025     0.500     0.975  \
#  0                                 rand10  0.009458  0.009761  0.010071
#  1            likelihood_logreg_clickpres  0.015224  0.015608  0.015998
#  2            likelihood_logreg_postdpres  0.007823  0.008099  0.008382
#  3           likelihood_saleclickprodpres  0.014994  0.015375  0.015762
#  4  likelihood_saleclickprod_discountpres  0.013398  0.013758  0.014125
#
#         Mean       std        se
#  0  0.009900  0.000153  0.000022
#  1  0.015971  0.000202  0.000029
#  2  0.008046  0.000132  0.000019
#  3  0.015706  0.000211  0.000030
#  4  0.013969  0.000204  0.000029  ,
#  'Tot sales ATT':                                    Agent  TotSalesAtt     Mean        std  \
#  0                                 rand10         1103  1177.44  45.567164
#  1            likelihood_logreg_clickpres         1973  2012.62  57.113883
#  2            likelihood_logreg_postdpres          918   931.40  36.944824
# ...

# %%
res_avg
(res_recap, res_recap_latex, 
 res_AB, res_AB_latex, 
 res_true, res_true_latex) = format_avg_result_extended(res_avg) #get dataframe & corresponding latex table
# Out:
# -- A/B test --
#    Agent              CTR Att Sales          Att CR       Sales  \
# 0   Rand  0.990 (0.002) %  1177 (6)  18.33 (0.08) %   9800 (29)
# 1  Click  1.597 (0.003) %  2012 (8)  27.02 (0.08) %  11385 (32)
# 2    PVS  0.805 (0.002) %   931 (5)  15.22 (0.07) %   9245 (25)
# 3    PCS  1.571 (0.003) %  1980 (8)  26.67 (0.08) %  11285 (33)
# 4   DPCS  1.397 (0.003) %  1738 (6)  24.17 (0.07) %  10842 (30)
#
#                CR
# 0  60.56 (0.08) %
# 1  63.81 (0.09) %
# 2  59.46 (0.09) %
# 3  63.49 (0.10) %
# 4  62.70 (0.09) %
# -- True metrics --
#    Agent         True CTR        True PCS        True OS        True NCS  \
# 0   Rand  0.963 (0.000) %  10.83 (0.01) %  7.52 (0.01) %   8.74 (0.01) %
# 1  Click  1.553 (0.001) %  11.94 (0.01) %  7.76 (0.01) %   9.96 (0.01) %
# 2    PVS  0.784 (0.001) %  11.67 (0.01) %  9.46 (0.01) %  10.22 (0.01) %
# 3    PCS  1.527 (0.001) %  11.88 (0.01) %  7.81 (0.01) %   9.92 (0.01) %
# ...

# %%
res_recap
# Out:
#    Agent              CTR Att Sales          Att CR       Sales  \
# 0   Rand  0.990 (0.002) %  1177 (6)  18.33 (0.08) %   9800 (29)
# 1  Click  1.597 (0.003) %  2012 (8)  27.02 (0.08) %  11385 (32)
# 2    PVS  0.805 (0.002) %   931 (5)  15.22 (0.07) %   9245 (25)
# 3    PCS  1.571 (0.003) %  1980 (8)  26.67 (0.08) %  11285 (33)
# 4   DPCS  1.397 (0.003) %  1738 (6)  24.17 (0.07) %  10842 (30)
#
#                CR         True CTR        True PCS        True OS  \
# 0  60.56 (0.08) %  0.963 (0.000) %  10.83 (0.01) %  7.52 (0.01) %
# 1  63.81 (0.09) %  1.553 (0.001) %  11.94 (0.01) %  7.76 (0.01) %
# 2  59.46 (0.09) %  0.784 (0.001) %  11.67 (0.01) %  9.46 (0.01) %
# 3  63.49 (0.10) %  1.527 (0.001) %  11.88 (0.01) %  7.81 (0.01) %
# 4  62.70 (0.09) %  1.359 (0.001) %  11.58 (0.01) %  7.91 (0.01) %
#
#          True NCS              NDPC             DPCSO             DPCSN
# 0   8.74 (0.01) %  1.043 (0.001) pm  0.319 (0.001) pm  0.201 (0.000) pm
# ...

# %%
res_avg = avg_result_extended(res_dict)
for k in res_avg.keys():
    print(k)
    display(res_avg[k])
# (res_recap, res_recap_latex, 
#  res_AB, res_AB_latex, 
#  res_true, res_true_latex) = format_avg_result_extended(res_avg) #get dataframe & corresponding latex table
# Out:
# CTR
#                                    Agent     0.025     0.500     0.975  \
# 0                                 rand10  0.009458  0.009761  0.010071
# 1            likelihood_logreg_clickpres  0.015224  0.015608  0.015998
# 2            likelihood_logreg_postdpres  0.007823  0.008099  0.008382
# 3           likelihood_saleclickprodpres  0.014994  0.015375  0.015762
# 4  likelihood_saleclickprod_discountpres  0.013398  0.013758  0.014125
#
#        Mean       std        se
# 0  0.009900  0.000153  0.000022
# 1  0.015971  0.000202  0.000029
# 2  0.008046  0.000132  0.000019
# 3  0.015706  0.000211  0.000030
# 4  0.013969  0.000204  0.000029
# Tot sales ATT
#                                    Agent  TotSalesAtt     Mean        std  \
# 0                                 rand10         1103  1177.44  45.567164
# 1            likelihood_logreg_clickpres         1973  2012.62  57.113883
# 2            likelihood_logreg_postdpres          918   931.40  36.944824
# ...

# %%
res_avg = pkl.load(open('data_conversion/clean/res_avg_rand105000_5000_v_sharepres.pkl','rb'))

# for k in res_avg.keys():
#     print(k)
#     display(res_avg[k])

# %%
res_avg['Tot sales ATT']
# Out:
#                                    Agent  TotSalesAtt          Mean  \
# 0                                 rand10         1103  6.628398e-81
# 1            likelihood_logreg_clickpres         1973  1.133004e-80
# 2            likelihood_logreg_postdpres          918  5.243316e-81
# 3           likelihood_saleclickprodpres         1944  1.114641e-80
# 4  likelihood_saleclickprod_discountpres         1715  9.784295e-81
#
#          std        se
# 0  45.567164  6.444170
# 1  57.113883  8.077123
# 2  36.944824  5.224787
# 3  58.192439  8.229654
# 4  46.694736  6.603633

# %%
name = 'res_rand105000_5000_v_sharepres_nb41likelihood_logreg_clickpres_full'
res = pkl.load(open('data_conversion_big/data_conversion/'+name+'.pkl','rb'))

### Number of clicks with a good policy!!
clicks = res['all_data'][['u','c']].groupby(['u']).sum()['c']

plt.xlabel('Number of clicks')
plt.ylabel('Number of users')
plt.hist(clicks,bins=np.arange(0,np.max(clicks)+1)-0.5,rwidth=0.9)
plt.show()
res['all_data']['sale'] = (res['all_data']['z'] == 'sale')*1
sales = res['all_data'][['u','sale']].groupby(['u']).sum()['sale']

plt.xlabel('Number of sales')
plt.ylabel('Number of users')
plt.hist(sales,bins=np.arange(0,np.max(sales)+1)-0.5,rwidth=0.9)
plt.show()

print(np.max(clicks))
np.mean(np.array(clicks==0))
# Out:
# 18.0
# 0.476

# %%
# name = 'res_rand10kap0.45000_5000_v_sharepreskap0.4_nb0likelihood_saleclickprod_discountpres_full'
# res = pkl.load(open('data_conversion_big/data_conversion/'+name+'.pkl','rb'))

### Number of clicks with a good policy!!
clicks = res['all_data'][['u','c']].groupby(['u']).sum()['c']

plt.xlabel('Number of clicks')
plt.ylabel('Number of users')
plt.hist(clicks,bins=np.arange(0,np.max(clicks)+1)-0.5,rwidth=0.9)
plt.show()
res['all_data']['sale'] = (res['all_data']['z'] == 'sale')*1
sales = res['all_data'][['u','sale']].groupby(['u']).sum()['sale']

plt.xlabel('Number of sales')
plt.ylabel('Number of users')
plt.hist(sales,bins=np.arange(0,np.max(sales)+1)-0.5,rwidth=0.9)
plt.show()

print(np.max(clicks))
np.mean(np.array(clicks==0))
# Out:
# 18.0
# 0.485

# %%
name = 'res_rand10kap0.65000_5000_v_sharepreskap0.6_nb0likelihood_saleclickprod_discountpres_full'
res = pkl.load(open('data_conversion_big/data_conversion/'+name+'.pkl','rb'))

### Number of clicks with a good policy!!
clicks = res['all_data'][['u','c']].groupby(['u']).sum()['c']

plt.xlabel('Number of clicks')
plt.ylabel('Number of users')
plt.hist(clicks,bins=np.arange(0,np.max(clicks)+1)-0.5,rwidth=0.9)

print(np.max(clicks))
np.mean(np.array(clicks==0))
# Out:
# 18.0
# 0.4876

# %%
repo = 'C:/Users/Philo/Documents/3A -- criteo/materiel_rapport/res_recap/'

# %%
list_files=['res_recap_rand10kap0.65000_5000_v_sharepreskap0.6',
           'res_recap_rand10kap0.65000_5000_v_sharepresweightskap0.6',
           'res_recap_rand10kap0.65000_5000_v_sharepropkap0.6',
           'res_recap_rand10kap0.65000_5000_v_sharepropweightskap0.6']

# %%
for f in list_files:
    df = pd.read_csv(repo+f+'.csv')
    print(f)
    df = df[['Agent','True CTR','True PCS','True OS','True NCS','NDPC','DPCSO','DPCSN']]
    display(df)
    print(df.to_latex(index=False))
# Out:
# res_recap_rand10kap0.65000_5000_v_sharepreskap0.6
#    Agent         True CTR        True PCS        True OS        True NCS  \
# 0   Rand  0.963 (0.000) %  13.91 (0.00) %  7.48 (0.02) %  10.01 (0.02) %
# 1  Click  1.552 (0.001) %  14.27 (0.00) %  7.73 (0.02) %  11.19 (0.02) %
# 2    PVS  0.793 (0.001) %  13.81 (0.01) %  9.10 (0.01) %  10.87 (0.01) %
# 3    PCS  1.547 (0.002) %  14.28 (0.00) %  7.64 (0.02) %  11.15 (0.02) %
# 4   DPCS  1.419 (0.002) %  14.34 (0.00) %  7.47 (0.02) %  10.95 (0.02) %
#
#                NDPC             DPCSO             DPCSN
# 0  1.340 (0.001) pm  0.620 (0.002) pm  0.376 (0.001) pm
# 1  2.214 (0.002) pm  1.014 (0.003) pm  0.477 (0.002) pm
# 2  1.094 (0.001) pm  0.374 (0.001) pm  0.233 (0.001) pm
# 3  2.210 (0.002) pm  1.028 (0.003) pm  0.485 (0.003) pm
# 4  2.035 (0.003) pm  0.975 (0.004) pm  0.481 (0.002) pm
# \begin{tabular}{llllllll}
# \toprule
# ...

# %%
x=0.001
x*(1-x)
# Out:
# 0.000999
